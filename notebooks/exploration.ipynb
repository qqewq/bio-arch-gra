# %% [markdown]
# # Bio-Arch GRA Experiment\nThis notebook demonstrates the synthesis of biological and architectural forms using GRA optimization.

# %%
import sys\nsys.path.append('..')\nfrom gra_biomimetic.optimizer import optimize\nfrom gra_biomimetic.visualizer import show_mesh\nimport numpy as np

# %%
# Parameters\nR_best, H_best, pores_best, fitness = optimize(\n    R_range=(0.1,0.5), H_range=(2.0,5.0), max_pores=6, lambda_bio=0.5,\n    F_target=500e3, m_target=100, p_target=0.5,\n    F_req=400e3, t_min=0.02, target_ratio=1.618,\n    pop_size=20, ngen=30\n)\nprint(f"Best fitness: {fitness:.4f}")

# %%
show_mesh(R_best, H_best, pores_best)
